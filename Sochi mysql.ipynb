# %%
import pymysql
import pymysql.cursors

#def mysqlconnect():
# Connect to the database
conn = pymysql.connect(host='localhost',
                             user='root',
                             password='Chigozie',
                             database='cen414',
                             cursorclass=pymysql.cursors.DictCursor)

cur = conn.cursor()
      
    # Select query
    
cur.execute("select * from cen414.sochi")
rows = cur.fetchall()

for row in rows:
    print(row)
# Out:
# {'s/n': 1, 'country': 'Cameroon', '2010': '20590666', '2011': '21119065', '2012': '21659488', '2013': '22211166', '2014': '22773014', '2015': '23344179', '2016': '23924407', '2017': '24513689', '2018': '25111719', '2019': '25718212'}
# {'s/n': 2, 'country': 'Central African Republic', '2010': '4444973', '2011': '4530903', '2012': '4619500', '2013': '4710678', '2014': '4804316', '2015': '4900274', '2016': '4998493', '2017': '5098826', '2018': '5200921', '2019': '5304347'}
# {'s/n': 3, 'country': 'Chad', '2010': '11896380', '2011': '12298512', '2012': '12715465', '2013': '13145788', '2014': '13587053', '2015': '14037472', '2016': '14496739', '2017': '14965482', '2018': '15443905', '2019': '15932433'}
# {'s/n': 4, 'country': 'Congo, Dem. Rep.', '2010': '65938712', '2011': '68087376', '2012': '70291160', '2013': '72552861', '2014': '74877030', '2015': '77266814', '2016': '79722624', '2017': '82242685', '2018': '84825354', '2019': '87468225'}
# ...
